# %%
import requests
import pandas as pd
from io import StringIO
import datetime
import dateutil
import matplotlib
matplotlib.use("webagg")
# %matplotlib notebook
import matplotlib.pyplot as plt
covid = pd.read_csv("covid.csv")
columns = covid.columns
dates = columns[12:]

# %%
 nc = covid[covid["Province_State"] == "North Carolina"]

# %%
nc=nc[nc["4/11/20"] > 100]
ax=nc[dates].T.plot( grid=True)
ax.legend(nc["Admin2"], loc="upper left")
ax.set_title("NC COVID19")
ax.set_ylabel("Number Infected")
ax.set_xlabel("Date")
# Out:
# <img src="data:image/png;base64,..." width="639.85">
# Text(0.5, 0, 'Date')

# %%
ax=covid[covid["Admin2"] == "Watauga"][dates].T.plot.bar()
ax.set_xticks(range(len(dates)))
n=[""]*len(dates)

n[::5] = dates[::5]

f=ax.set_xticklabels(n)
#pd.to_datetime(dates)
#|covid[covid["Admin2"] == "Watauga"][dates].T.index
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
f=list(range(10))
f[::2] = [""]*len(f[::2])
f
# Out:
# ['', 1, '', 3, '', 5, '', 7, '', 9]

# %%
pd.to_datetime
